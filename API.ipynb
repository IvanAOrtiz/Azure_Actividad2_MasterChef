# %% [markdown]
# # APLICACIÓN DE LA API

# %%
import pandas as pd

#input_data = input("Introduce path for data")
data = pd.read_csv("testapi.csv")
data_dict = data.to_dict(orient='list')

data
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.128663 -1.595254  0.858068 -1.941674  0.164878  0.237919  0.514694
# 1 -1.690968 -1.575963 -0.456906 -0.601297 -0.112064 -0.322132 -1.231575
# 2 -3.413149  0.496334  1.623365  2.327541 -0.681955  2.068346  0.285685
# 3 -2.475455 -1.355050  2.578546  2.785472 -0.884563  0.191082  0.168952
# 4  1.045206  0.809215  1.184283  1.888430 -0.321348  1.106399  0.643379
#
#           7         8         9  ...        43        44        45        46  \
# 0 -0.327606 -0.082105 -0.993985  ... -0.789815 -0.340522  0.108396 -0.261017
# 1  1.180397 -1.209120 -0.307961  ... -0.593923 -0.323844  0.101308 -0.170111
# 2 -1.332325  0.069928  0.205970  ...  0.279354 -0.849530 -0.672272 -0.076523
# 3 -0.687776  0.103172  0.089444  ... -0.378602  0.259648 -0.308975  0.070118
# 4 -1.156735  0.705574  0.908514  ... -1.200772 -1.378945 -1.127354 -0.797889
#
#          47        48        49        50        51        52
# 0  0.244645  0.357488  0.345566 -0.397126  0.751604 -0.613768
# 1 -0.358602 -0.112397 -0.174378  1.024474 -1.123804 -0.360140
# 2 -0.235850 -0.168099  0.018724  0.704721 -0.478856  0.464973
# 3 -0.149564 -0.086378 -0.034182  0.680112 -0.475525  0.031812
# 4 -0.115947 -0.066175  0.293434  0.272591  0.032325  0.476915
#
# [5 rows x 53 columns]

# %%
import json

#Formateado para la API:
data_json = json.dumps({"data": [data_dict]})

suri = open("uri.json", "r")
scoring_uri = json.load(suri)["URI"][0]
suri.close()

# %%
## La API per-sé:

headers = {"Content-Type": "application/json"}
import requests
response = requests.post(scoring_uri, data=data_json, headers=headers)

if response.status_code == 200:
  result = json.loads(response.json())
  print(result)
  data["Exited"] = result
  display(data)
else:
  print(f"Error: {response.text}")
# Out:
# [0, 0, 0, 0, 0]
#           0         1         2         3         4         5         6  \
# 0  1.128663 -1.595254  0.858068 -1.941674  0.164878  0.237919  0.514694
# 1 -1.690968 -1.575963 -0.456906 -0.601297 -0.112064 -0.322132 -1.231575
# 2 -3.413149  0.496334  1.623365  2.327541 -0.681955  2.068346  0.285685
# 3 -2.475455 -1.355050  2.578546  2.785472 -0.884563  0.191082  0.168952
# 4  1.045206  0.809215  1.184283  1.888430 -0.321348  1.106399  0.643379
#
#           7         8         9  ...        44        45        46        47  \
# 0 -0.327606 -0.082105 -0.993985  ... -0.340522  0.108396 -0.261017  0.244645
# 1  1.180397 -1.209120 -0.307961  ... -0.323844  0.101308 -0.170111 -0.358602
# 2 -1.332325  0.069928  0.205970  ... -0.849530 -0.672272 -0.076523 -0.235850
# 3 -0.687776  0.103172  0.089444  ...  0.259648 -0.308975  0.070118 -0.149564
# 4 -1.156735  0.705574  0.908514  ... -1.378945 -1.127354 -0.797889 -0.115947
#
#          48        49        50        51        52  Exited
# 0  0.357488  0.345566 -0.397126  0.751604 -0.613768       0
# 1 -0.112397 -0.174378  1.024474 -1.123804 -0.360140       0
# 2 -0.168099  0.018724  0.704721 -0.478856  0.464973       0
# 3 -0.086378 -0.034182  0.680112 -0.475525  0.031812       0
# 4 -0.066175  0.293434  0.272591  0.032325  0.476915       0
#
# [5 rows x 54 columns]
